# %%
# import pandas 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import metrics

# %%
pdf = pd.read_csv('Weather_Data.csv')
pdf.head()
# Out:
#        Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  2/1/2008     19.5     22.4      15.6          6.2       0.0           W
# 1  2/2/2008     19.5     25.6       6.0          3.4       2.7           W
# 2  2/3/2008     21.6     24.5       6.6          2.4       0.1           W
# 3  2/4/2008     20.2     22.8      18.8          2.2       0.0           W
# 4  2/5/2008     19.7     25.7      77.4          4.8       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0             41          S        SSW  ...           92           84
# 1             41          W          E  ...           83           73
# 2             41        ESE        ESE  ...           88           86
# 3             41        NNE          E  ...           83           90
# 4             41        NNE          W  ...           88           74
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1017.6       1017.4         8         8     20.7     20.9        Yes
# 1       1017.9       1016.4         7         7     22.4     24.8        Yes
# 2       1016.7       1015.6         7         8     23.5     23.0        Yes
# 3       1014.2       1011.8         8         8     21.4     20.9        Yes
# 4       1008.3       1004.8         8         8     22.5     25.5        Yes
#
#    RainTomorrow
# 0           Yes
# 1           Yes
# 2           Yes
# 3           Yes
# 4           Yes
#
# [5 rows x 22 columns]

# %%
pdf.nunique()
# Out:
# Date             3271
# MinTemp           204
# MaxTemp           247
# Rainfall          208
# Evaporation        82
# Sunshine          137
# WindGustDir        16
# WindGustSpeed      44
# WindDir9am         16
# WindDir3pm         16
# WindSpeed9am       26
# WindSpeed3pm       29
# Humidity9am        80
# Humidity3pm        86
# Pressure9am       361
# Pressure3pm       369
# Cloud9am           10
# Cloud3pm            9
# Temp9am           229
# Temp3pm           240
# RainToday           2
# RainTomorrow        2
# dtype: int64

# %%
pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3271 non-null   object
#  1   MinTemp        3271 non-null   float64
#  2   MaxTemp        3271 non-null   float64
#  3   Rainfall       3271 non-null   float64
#  4   Evaporation    3271 non-null   float64
#  5   Sunshine       3271 non-null   float64
#  6   WindGustDir    3271 non-null   object
#  7   WindGustSpeed  3271 non-null   int64
#  8   WindDir9am     3271 non-null   object
#  9   WindDir3pm     3271 non-null   object
#  10  WindSpeed9am   3271 non-null   int64
#  11  WindSpeed3pm   3271 non-null   int64
#  12  Humidity9am    3271 non-null   int64
#  13  Humidity3pm    3271 non-null   int64
#  14  Pressure9am    3271 non-null   float64
#  15  Pressure3pm    3271 non-null   float64
#  16  Cloud9am       3271 non-null   int64
#  17  Cloud3pm       3271 non-null   int64
#  18  Temp9am        3271 non-null   float64
#  19  Temp3pm        3271 non-null   float64
#  20  RainToday      3271 non-null   object
#  21  RainTomorrow   3271 non-null   object
# dtypes: float64(9), int64(7), object(6)
# memory usage: 562.3+ KB

# %%
# Few Data preprocessing

# remove unwanted labels...

# remove Data column
pdf.drop('Date', axis=1, inplace=True)

pdf_processed = pd.get_dummies(data=pdf, columns=['WindGustDir', 'WindDir9am', 'WindDir3pm'])

# %%
pdf_processed.shape
# Out:
# (3271, 66)

# %%
pdf_processed['RainToday']
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 3266     No
# 3267     No
# 3268     No
# 3269     No
# 3270     No
# Name: RainToday, Length: 3271, dtype: object

# %%
# replace 'Yes/True' and 'No/False' with binary indicators.

pdf_processed = pdf_processed.replace(['Yes', 'No'], [1, 0])
pdf_processed = pdf_processed.replace([True, False], [1, 0])

# %%
pdf_processed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 66 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MinTemp          3271 non-null   float64
#  1   MaxTemp          3271 non-null   float64
#  2   Rainfall         3271 non-null   float64
#  3   Evaporation      3271 non-null   float64
#  4   Sunshine         3271 non-null   float64
#  5   WindGustSpeed    3271 non-null   int64
#  6   WindSpeed9am     3271 non-null   int64
#  7   WindSpeed3pm     3271 non-null   int64
#  8   Humidity9am      3271 non-null   int64
#  9   Humidity3pm      3271 non-null   int64
#  10  Pressure9am      3271 non-null   float64
#  11  Pressure3pm      3271 non-null   float64
#  12  Cloud9am         3271 non-null   int64
#  13  Cloud3pm         3271 non-null   int64
#  14  Temp9am          3271 non-null   float64
#  15  Temp3pm          3271 non-null   float64
#  16  RainToday        3271 non-null   int64
#  17  RainTomorrow     3271 non-null   int64
#  18  WindGustDir_E    3271 non-null   int64
#  19  WindGustDir_ENE  3271 non-null   int64
#  20  WindGustDir_ESE  3271 non-null   int64
#  21  WindGustDir_N    3271 non-null   int64
#  22  WindGustDir_NE   3271 non-null   int64
#  23  WindGustDir_NNE  3271 non-null   int64
#  24  WindGustDir_NNW  3271 non-null   int64
#  25  WindGustDir_NW   3271 non-null   int64
#  26  WindGustDir_S    3271 non-null   int64
#  27  WindGustDir_SE   3271 non-null   int64
#  28  WindGustDir_SSE  3271 non-null   int64
#  29  WindGustDir_SSW  3271 non-null   int64
#  30  WindGustDir_SW   3271 non-null   int64
#  31  WindGustDir_W    3271 non-null   int64
#  32  WindGustDir_WNW  3271 non-null   int64
#  33  WindGustDir_WSW  3271 non-null   int64
#  34  WindDir9am_E     3271 non-null   int64
#  35  WindDir9am_ENE   3271 non-null   int64
#  36  WindDir9am_ESE   3271 non-null   int64
#  37  WindDir9am_N     3271 non-null   int64
#  38  WindDir9am_NE    3271 non-null   int64
#  39  WindDir9am_NNE   3271 non-null   int64
#  40  WindDir9am_NNW   3271 non-null   int64
#  41  WindDir9am_NW    3271 non-null   int64
#  42  WindDir9am_S     3271 non-null   int64
#  43  WindDir9am_SE    3271 non-null   int64
#  44  WindDir9am_SSE   3271 non-null   int64
#  45  WindDir9am_SSW   3271 non-null   int64
#  46  WindDir9am_SW    3271 non-null   int64
#  47  WindDir9am_W     3271 non-null   int64
#  48  WindDir9am_WNW   3271 non-null   int64
#  49  WindDir9am_WSW   3271 non-null   int64
#  50  WindDir3pm_E     3271 non-null   int64
#  51  WindDir3pm_ENE   3271 non-null   int64
#  52  WindDir3pm_ESE   3271 non-null   int64
#  53  WindDir3pm_N     3271 non-null   int64
#  54  WindDir3pm_NE    3271 non-null   int64
#  55  WindDir3pm_NNE   3271 non-null   int64
#  56  WindDir3pm_NNW   3271 non-null   int64
#  57  WindDir3pm_NW    3271 non-null   int64
#  58  WindDir3pm_S     3271 non-null   int64
#  59  WindDir3pm_SE    3271 non-null   int64
#  60  WindDir3pm_SSE   3271 non-null   int64
#  61  WindDir3pm_SSW   3271 non-null   int64
#  62  WindDir3pm_SW    3271 non-null   int64
#  63  WindDir3pm_W     3271 non-null   int64
#  64  WindDir3pm_WNW   3271 non-null   int64
#  65  WindDir3pm_WSW   3271 non-null   int64
# dtypes: float64(9), int64(57)
# memory usage: 1.6 MB

# %%
# checking out the correlation
pdf_processed.corr(numeric_only=True)
# Out:
#                  MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp         1.000000  0.771005  0.013995     0.569316 -0.063475
# MaxTemp         0.771005  1.000000 -0.139306     0.510334  0.327422
# Rainfall        0.013995 -0.139306  1.000000    -0.110343 -0.308962
# Evaporation     0.569316  0.510334 -0.110343     1.000000  0.175932
# Sunshine       -0.063475  0.327422 -0.308962     0.175932  1.000000
# ...                  ...       ...       ...          ...       ...
# WindDir3pm_SSW -0.131773 -0.213966  0.112996    -0.101030 -0.168845
# WindDir3pm_SW  -0.074196 -0.087241  0.036072    -0.051831 -0.059655
# WindDir3pm_W   -0.165429 -0.114668 -0.034273    -0.062852  0.033344
# WindDir3pm_WNW -0.129172 -0.017097 -0.049959    -0.072257  0.066551
# WindDir3pm_WSW -0.135055 -0.108176  0.020607    -0.007111  0.041486
#
#                 WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  \
# MinTemp              0.127792     -0.298040      0.225905     0.053946
# MaxTemp              0.073184     -0.349382      0.155542    -0.185382
# Rainfall             0.149811      0.153696      0.039415     0.332636
# Evaporation          0.245426     -0.077532      0.292469    -0.395651
# Sunshine            -0.029032     -0.058410      0.177813    -0.490631
# ...                       ...           ...           ...          ...
# WindDir3pm_SSW       0.096481      0.137927      0.033670     0.082297
# WindDir3pm_SW        0.067767      0.077584     -0.031000     0.001275
# WindDir3pm_W         0.100644      0.096074      0.096827    -0.134868
# WindDir3pm_WNW       0.063259      0.055324     -0.031216    -0.139134
# WindDir3pm_WSW       0.131907      0.124057      0.051958    -0.137359
#
#                 Humidity3pm  ...  WindDir3pm_NNW  WindDir3pm_NW  WindDir3pm_S  \
# MinTemp            0.273269  ...       -0.006096      -0.057882     -0.075180
# MaxTemp           -0.150741  ...        0.058478      -0.001910     -0.151647
# Rainfall           0.305635  ...       -0.020313      -0.017927      0.096411
# Evaporation       -0.102295  ...       -0.016018      -0.047131     -0.051291
# Sunshine          -0.586476  ...       -0.013700      -0.004798     -0.115154
# ...                     ...  ...             ...            ...           ...
# WindDir3pm_SSW     0.131597  ...       -0.023685      -0.029608     -0.062162
# WindDir3pm_SW     -0.019017  ...       -0.012215      -0.015270     -0.032058
# WindDir3pm_W      -0.235915  ...       -0.027741      -0.034679     -0.072808
# WindDir3pm_WNW    -0.277288  ...       -0.026392      -0.032993     -0.069268
# WindDir3pm_WSW    -0.196635  ...       -0.020319      -0.025401     -0.053329
#
#                 WindDir3pm_SE  WindDir3pm_SSE  WindDir3pm_SSW  WindDir3pm_SW  \
# MinTemp              0.071836        0.025171       -0.131773      -0.074196
# MaxTemp              0.008442       -0.050886       -0.213966      -0.087241
# Rainfall             0.044433        0.053711        0.112996       0.036072
# Evaporation          0.069001        0.031471       -0.101030      -0.051831
# Sunshine            -0.065347       -0.091772       -0.168845      -0.059655
# ...                       ...             ...             ...            ...
# WindDir3pm_SSW      -0.057801       -0.066055        1.000000      -0.024613
# WindDir3pm_SW       -0.029809       -0.034066       -0.024613       1.000000
# WindDir3pm_W        -0.067700       -0.077368       -0.055899      -0.028828
# WindDir3pm_WNW      -0.064409       -0.073607       -0.053182      -0.027427
# WindDir3pm_WSW      -0.049588       -0.056670       -0.040944      -0.021116
#
#                 WindDir3pm_W  WindDir3pm_WNW  WindDir3pm_WSW
# MinTemp            -0.165429       -0.129172       -0.135055
# MaxTemp            -0.114668       -0.017097       -0.108176
# Rainfall           -0.034273       -0.049959        0.020607
# Evaporation        -0.062852       -0.072257       -0.007111
# Sunshine            0.033344        0.066551        0.041486
# ...                      ...             ...             ...
# WindDir3pm_SSW     -0.055899       -0.053182       -0.040944
# WindDir3pm_SW      -0.028828       -0.027427       -0.021116
# WindDir3pm_W        1.000000       -0.062290       -0.047956
# WindDir3pm_WNW     -0.062290        1.000000       -0.045625
# WindDir3pm_WSW     -0.047956       -0.045625        1.000000
#
# [66 rows x 66 columns]

# %%
# final part of preprocessing
y_data = pdf_processed['RainTomorrow']
x_data = pdf_processed.drop(columns='RainTomorrow', axis=1)

# %%
# segmenting Dataset
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, shuffle=True)

# %%
x_test.shape
# Out:
# (655, 65)

# %%
# creating LR Model
model = linear_model.LinearRegression()

# %%
# training model
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# determine loss of the model

prediction = model.predict(x_test)

loss = metrics.mean_absolute_error(y_test, prediction)

# %%
loss
# Out:
# 0.25678071466111047
